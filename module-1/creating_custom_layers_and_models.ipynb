# %%
# %pip install tensorflow==2.16.2
# %pip install pydot graphviz
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [graphviz]
# ...
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer
from tensorflow.keras.models import Sequential

# %% [markdown]
# Define a custom layer

# %%
class CustomDenseLayer(Layer):
    def __init__(self, units=32):
        super(CustomDenseLayer, self).__init__()
        self.units = units

    def build(self, input_shape):
        self.w = self.add_weight(shape=(input_shape[-1], self.units),
                                 initializer='random_normal',
                                 trainable=True)
        self.b = self.add_weight(shape=(self.units,),
                                 initializer='zeros',
                                 trainable=True)
    def call(self, inputs):
        return tf.nn.relu(tf.matmul(inputs, self.w) + self.b)

# %% [markdown]
# Integrate the custom layer into a model

# %%
from tensorflow.keras.layers import Softmax

# Define the model with Softmax in the output layer
model = Sequential([
    CustomDenseLayer(128),
    CustomDenseLayer(10),  # Hidden layer with ReLU activation
    Softmax()              # Output layer with Softmax activation for multi-class classification
])

# %% [markdown]
# Compile the model

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy')
print("Model summary before building:")
model.summary()

# Build the model to show parameters
model.build((1000, 20))
print("\nModel summary after building:")
model.summary()
# Out:
# Model summary before building:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ custom_dense_layer              │ ?                      │   0 (unbuilt) │
# │ (CustomDenseLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ custom_dense_layer_1            │ ?                      │   0 (unbuilt) │
# │ (CustomDenseLayer)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ softmax (Softmax)               │ ?                      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
# ...

# %% [markdown]
# Train the model

# %%
import numpy as np 

# Generate random data 
x_train = np.random.random((1000, 20)) 
y_train = np.random.randint(10, size=(1000, 1)) 

# Convert labels to categorical one-hot encoding 
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10) 
model.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 943us/step - loss: 2.3026
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2993
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2974
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 2.2952
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - loss: 2.2923
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 2.2911
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - loss: 2.2860
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 2.2837
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 2.2801
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 2.2775

# %% [markdown]
# Conceitos durante o fit:
#
# Batches: com 1000 amostras e batch_size=32, o Keras fará 32 batches por época (31 batches de 32 + 1 batch final com 8 amostras).
#
# Forward pass: para cada batch, o modelo produz logits → o Softmax converte para probabilidades.
#
# Loss: a categorical_crossentropy compara as probabilidades previstas com os vetores one-hot verdadeiros para calcular o erro.
#
# Backward pass (backpropagation): o otimizador (configurado antes com adam) ajusta os pesos e vieses para minimizar a loss.
#
# Métricas: se nenhuma métrica foi definida no compile, o fit reporta apenas a loss por época (e por batch se verbose permitir).

# %% [markdown]
#  Evaluate the model

# %%
# Generate random test data 
x_test = np.random.random((200, 20)) 
y_test = np.random.randint(10, size=(200, 1)) 

# Convert labels to categorical one-hot encoding 
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10) 

# Evaluate the model 
loss = model.evaluate(x_test, y_test) 
print(f'Test loss: {loss}')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3076
# Test loss: 2.3076488971710205

# %% [markdown]
# Exercise 1: Visualize Model Architecture
#
# Objective: Visualize the architecture of the custom Keras model to understand its structure.

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_architeture.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %% [markdown]
# Exercise 2: Add Dropout Layer
#
# Objective: Enhance the model by adding a Dropout layer to prevent overfitting.

# %%
from tensorflow.keras.layers import Dropout

# Modify the model to include a Dropout layer
model = Sequential([
    CustomDenseLayer(64),
    Dropout(0.5),
    CustomDenseLayer(10)
])

# Recompile the model
model.compile(optimizer='adam', loss='categorical_crossentropy')

# Train the model again
model.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 7.0506
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8067
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 2.7427
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4591
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3891
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3396
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 2.3662
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3325
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3645
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3216

# %% [markdown]
# Exercise 3: Adjust the Number of Units in Custom Layer
#
# Objective: Experiment with different numbers of units in the custom dense layer to observe the impact on performance.

# %%
from tensorflow.keras.layers import Dropout

# Modify the model to include a Dropout layer
model = Sequential([
    CustomDenseLayer(128),
    Dropout(0.5),
    CustomDenseLayer(10)
])

# Recompile the model
model.compile(optimizer='adam', loss='categorical_crossentropy')

# Train the model again
model.fit(x_train, y_train, epochs=10, batch_size=64)
# Out:
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3090
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0909
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5376
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4297
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3349
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3660
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3231
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3189
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3339
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3218

# %%
# Define a custom layer with 128 units
class CustomDenseLayer(Layer):
    def __init__(self, units=128):
        super(CustomDenseLayer, self).__init__()
        self.units = units

    def build(self, input_shape):
        self.w = self.add_weight(shape=(input_shape[-1], self.units),
                                 initializer='random_normal',
                                 trainable=True)
        self.b = self.add_weight(shape=(self.units,),
                                 initializer='zeros',
                                 trainable=True)

    def call(self, inputs):
        return tf.nn.relu(tf.matmul(inputs, self.w) + self.b)

# Integrate the new custom layer into a model
model = Sequential([
    CustomDenseLayer(128),
    CustomDenseLayer(10)
])

# Recompile the model
model.compile(optimizer='adam', loss='categorical_crossentropy')

# Train the model again
model.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.1206
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7745
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 4.7668
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 4.7608
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 4.7506
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 4.7482
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7341
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 4.7250
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7135
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7154
