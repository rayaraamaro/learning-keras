# %%
# Install TensorFlow
# %pip install tensorflow==2.16.2

import tensorflow as tf 
from tensorflow.keras.models import Model 
from tensorflow.keras.layers import Input, Dense 
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='tensorflow')
# Out:
# Collecting tensorflow==2.16.2
#   Downloading tensorflow-2.16.2-cp311-cp311-macosx_12_0_arm64.whl.metadata (4.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow==2.16.2)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow==2.16.2)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/rayaraamaro/Library/Python/3.11/lib/python/site-packages (from tensorflow==2.16.2) (25.2.10)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow==2.16.2)
#   Downloading gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow==2.16.2)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=3.10.0 (from tensorflow==2.16.2)
#   Downloading h5py-3.15.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting libclang>=13.0.0 (from tensorflow==2.16.2)
#   Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting ml-dtypes~=0.3.1 (from tensorflow==2.16.2)
#   Downloading ml_dtypes-0.3.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (20 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow==2.16.2)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.16.2) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow==2.16.2)
#   Downloading protobuf-4.25.8-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.16.2) (2.32.2)
# Requirement already satisfied: setuptools in /Users/rayaraamaro/Library/Python/3.11/lib/python/site-packages (from tensorflow==2.16.2) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.16.2) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow==2.16.2)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.16.2) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/rayaraamaro/Library/Python/3.11/lib/python/site-packages (from tensorflow==2.16.2) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/rayaraamaro/Library/Python/3.11/lib/python/site-packages (from tensorflow==2.16.2) (1.71.0)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow==2.16.2)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.0.0 (from tensorflow==2.16.2)
#   Downloading keras-3.13.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow==2.16.2)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow==2.16.2) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2) (3.7)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.17,>=2.16->tensorflow==2.16.2)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.17,>=2.16->tensorflow==2.16.2)
#   Downloading werkzeug-3.1.6-py3-none-any.whl.metadata (4.0 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow==2.16.2)
#   Downloading wheel-0.46.3-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: rich in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow==2.16.2) (13.9.4)
# Collecting namex (from keras>=3.0.0->tensorflow==2.16.2)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.0.0->tensorflow==2.16.2)
#   Downloading optree-0.19.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (34 kB)
# Requirement already satisfied: markupsafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.2) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.2) (0.1.2)
# Downloading tensorflow-2.16.2-cp311-cp311-macosx_12_0_arm64.whl (227.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.0/227.0 MB 18.0 MB/s  0:00:12m0:00:0100:01
# Downloading ml_dtypes-0.3.2-cp311-cp311-macosx_10_9_universal2.whl (389 kB)
# Downloading protobuf-4.25.8-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 33.0 MB/s  0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading wheel-0.46.3-py3-none-any.whl (30 kB)
# Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.15.1-cp311-cp311-macosx_11_0_arm64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 44.4 MB/s  0:00:00
# Downloading keras-3.13.2-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 31.4 MB/s  0:00:00
# Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 45.6 MB/s  0:00:00 eta 0:00:01
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-macosx_12_0_arm64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 40.8 MB/s  0:00:00
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading werkzeug-3.1.6-py3-none-any.whl (225 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.19.0-cp311-cp311-macosx_11_0_arm64.whl (378 kB)
# Installing collected packages: namex, libclang, wheel, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, protobuf, optree, opt-einsum, ml-dtypes, h5py, google-pasta, gast, absl-py, tensorboard, astunparse, keras, tensorflow
#   Attempting uninstall: protobufm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/19 [werkzeug]
#     Found existing installation: protobuf 5.29.3━━━━━━━━━━━━━━  3/19 [werkzeug]
#     Uninstalling protobuf-5.29.3:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/19 [werkzeug]
#       Successfully uninstalled protobuf-5.29.3━━━━━━━━━━━━━━━━  3/19 [werkzeug]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19/19 [tensorflow]9 [tensorflow]]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-proto 1.33.1 requires protobuf<6.0,>=5.0, but you have protobuf 4.25.8 which is incompatible.
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 gast-0.7.0 google-pasta-0.2.0 h5py-3.15.1 keras-3.13.2 libclang-18.1.1 ml-dtypes-0.3.2 namex-0.1.0 opt-einsum-3.4.0 optree-0.19.0 protobuf-4.25.8 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.2 tensorflow-io-gcs-filesystem-0.37.1 termcolor-3.3.0 werkzeug-3.1.6 wheel-0.46.3
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Define the Input Layer

# %%
input_layer = Input(shape=(20,))
print(input_layer)
# Out:
# <KerasTensor shape=(None, 20), dtype=float32, sparse=False, ragged=False, name=keras_tensor>

# %% [markdown]
# Add Hidden Layers

# %%
hidden_layer1 = Dense(64, activation='relu')(input_layer) 
hidden_layer2 = Dense(64, activation='relu')(hidden_layer1)

# %% [markdown]
# Explanation:
#
# Dense(64, activation='relu') creates a dense (fully connected) layer with 64 units and ReLU activation function.
#
# Each hidden layer takes the output of the previous layer as its input.

# %% [markdown]
# Define the Output Layer

# %%
output_layer = Dense(1, activation='sigmoid')(hidden_layer2)

# %% [markdown]
# Explanation:
#
# Dense(1, activation='sigmoid') creates a dense layer with 1 unit and a sigmoid activation function, suitable for binary classification.

# %% [markdown]
# Create the Model

# %%
model = Model(inputs=input_layer, outputs=output_layer)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,569 (21.75 KB)
#  Trainable params: 5,569 (21.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Explanation:
#
# Model(inputs=input_layer, outputs=output_layer) creates a Keras model that connects the input layer to the output layer through the hidden layers.
#
# model.summary() provides a summary of the model, showing the layers, their shapes, and the number of parameters. This helps you interpret the model architecture.

# %% [markdown]
# Compile the Model

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Explanation:
#
# optimizer='adam' specifies the Adam optimizer, a popular choice for training neural networks.
#
# loss='binary_crossentropy' specifies the loss function for binary classification problems.
#
# metrics=['accuracy'] instructs Keras to evaluate the model using accuracy during training.

# %% [markdown]
# Train the Model

# %%
# Example data (in practice, use real dataset) 

import numpy as np 
X_train = np.random.rand(1000, 20) 
y_train = np.random.randint(2, size=(1000, 1)) 
model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4920 - loss: 0.6982
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5230 - loss: 0.6907
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5390 - loss: 0.6909
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.5350 - loss: 0.6895
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 0.5650 - loss: 0.6851
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.5290 - loss: 0.6859
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - accuracy: 0.5480 - loss: 0.6836
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5700 - loss: 0.6792
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - accuracy: 0.5940 - loss: 0.6774
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.5800 - loss: 0.6762

# %% [markdown]
# Explanation:
#
# X_train and y_train are placeholders for your actual training data.
#
# model.fit trains the model for a specified number of epochs and batch size.

# %% [markdown]
# Evaluate the Model

# %%
# Example test data (in practice, use real dataset) 

X_test = np.random.rand(200, 20) 
y_test = np.random.randint(2, size=(200, 1)) 
loss, accuracy = model.evaluate(X_test, y_test) 
print(f'Test loss: {loss}') 
print(f'Test accuracy: {accuracy}')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4250 - loss: 0.7137
# Test loss: 0.7136715650558472
# Test accuracy: 0.42500001192092896

# %% [markdown]
# Explanation:
#
# model.evaluate computes the loss and accuracy of the model on test data.
#
# X_test and y_test are placeholders for your actual test data.

# %% [markdown]
#  Dropout Layers and Batch Normalization.

# %%
from tensorflow.keras.layers import Dropout, Dense, Input
from tensorflow.keras.models import Model

# Define the input layer
input_layer = Input(shape=(20,))

# Add a hidden layer
hidden_layer = Dense(64, activation='relu')(input_layer)

# Add a Dropout layer
dropout_layer = Dropout(rate=0.5)(hidden_layer)

# Add another hidden layer after Dropout
hidden_layer2 = Dense(64, activation='relu')(dropout_layer)

# Define the output layer
output_layer = Dense(1, activation='sigmoid')(hidden_layer2)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Summary of the model
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,569 (21.75 KB)
#  Trainable params: 5,569 (21.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.layers import BatchNormalization, Dense, Input
from tensorflow.keras.models import Model

# Define the input layer
input_layer = Input(shape=(20,))

# Add a hidden layer
hidden_layer = Dense(64, activation='relu')(input_layer)

# Add a BatchNormalization layer
batch_norm_layer = BatchNormalization()(hidden_layer)

# Add another hidden layer after BatchNormalization
hidden_layer2 = Dense(64, activation='relu')(batch_norm_layer)

# Define the output layer
output_layer = Dense(1, activation='sigmoid')(hidden_layer2)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)

# Summary of the model
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,825 (22.75 KB)
#  Trainable params: 5,697 (22.25 KB)
#  Non-trainable params: 128 (512.00 B)

# %% [markdown]
# Exercise 1: Add Dropout Layers
#
# Objective: Learn to add dropout layers to prevent overfitting.
#
# Instructions:
#
# Add dropout layers after each hidden layer in the model.
# Set the dropout rate to 0.5.
# Recompile, train, and evaluate the model.

# %%
from tensorflow.keras.layers import Dropout, Input, Dense
from tensorflow.keras.models import Model

#definir a camada de entrada
input_layer=Input(shape=(20,)) #shape = numeros de vetores de entrada

#add camadas ocultas com dropout
hidden_layer1=Dense(64, activation='relu')(input_layer)
dropout1=Dropout(0.5)(hidden_layer1)
hidden_layer2=Dense(64, activation='relu')(dropout1)
dropout2=Dropout(0.5)(hidden_layer2)

#definir a camada de saida
output_layer=Dense(1,activation='sigmoid')(dropout2)

#create the model
model = Model(inputs=input_layer,outputs=output_layer)
model.summary()

#compilar o modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

#treinar o modelo
model.fit(X_train, y_train, epochs=10, batch_size=32)

#avaliar desempenho do modelo
loss, accuracy=model.evaluate(X_test, y_test)
print(f'Test loss: {loss}')
print(f'Test accuracy: {accuracy}')
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,569 (21.75 KB)
#  Trainable params: 5,569 (21.75 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4810 - loss: 0.7237
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5300 - loss: 0.6989
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4990 - loss: 0.7090
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4980 - loss: 0.6982
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5420 - loss: 0.6907
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5060 - loss: 0.6974
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5490 - loss: 0.6882
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5260 - loss: 0.6920
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5210 - loss: 0.6932
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5120 - loss: 0.6925
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5200 - loss: 0.6951
# Test loss: 0.6951415538787842
# Test accuracy: 0.5199999809265137

# %% [markdown]
# Exercise 2: Change Activation Functions
#
# Objective: Experiment with different activation functions.
#
# Instructions:
#
# Change the activation function of the hidden layers from ReLU to Tanh.
# Recompile, train, and evaluate the model to see the effect.

# %%
from tensorflow.keras.layers import Dropout, Input, Dense
from tensorflow.keras.models import Model

#definir a camada de entrada
input_layer=Input(shape=(20,)) #shape = numeros de vetores de entrada

#add camadas ocultas com dropout
hidden_layer1=Dense(64, activation='tanh')(input_layer)
dropout1=Dropout(0.5)(hidden_layer1)
hidden_layer2=Dense(64, activation='tanh')(dropout1)
dropout2=Dropout(0.5)(hidden_layer2)

#definir a camada de saida
output_layer=Dense(1,activation='sigmoid')(dropout2)

#create the model
model = Model(inputs=input_layer,outputs=output_layer)
model.summary()

#compilar o modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

#treinar o modelo
model.fit(X_train, y_train, epochs=10, batch_size=32)

#avaliar desempenho do modelo
loss, accuracy=model.evaluate(X_test, y_test)
print(f'Test loss: {loss}')
print(f'Test accuracy: {accuracy}')
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,569 (21.75 KB)
#  Trainable params: 5,569 (21.75 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4790 - loss: 0.7701
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4770 - loss: 0.7414
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5090 - loss: 0.7250
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - accuracy: 0.5210 - loss: 0.7150
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5060 - loss: 0.7172
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5290 - loss: 0.7022
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4990 - loss: 0.7181
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - accuracy: 0.5180 - loss: 0.7103
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5270 - loss: 0.7147
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5120 - loss: 0.7050
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4350 - loss: 0.7083
# Test loss: 0.7082558274269104
# Test accuracy: 0.4350000023841858

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
#exemplo do laboratorio para a resposta desse exercicio
# Define the input layer
input_layer = Input(shape=(20,))

# Add hidden layers with Tanh activation
hidden_layer1 = Dense(64, activation='tanh')(input_layer)
hidden_layer2 = Dense(64, activation='tanh')(hidden_layer1)

# Define the output layer
output_layer = Dense(1, activation='sigmoid')(hidden_layer2)

# Create the model
model = Model(inputs=input_layer, outputs=output_layer)
model.summary()

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test loss: {loss}')
print(f'Test accuracy: {accuracy}')
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,569 (21.75 KB)
#  Trainable params: 5,569 (21.75 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5170 - loss: 0.7056
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5150 - loss: 0.6944
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5280 - loss: 0.6974
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.5160 - loss: 0.6983
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.5090 - loss: 0.6983
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - accuracy: 0.5160 - loss: 0.6905
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.5230 - loss: 0.6928
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.5210 - loss: 0.6892
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.5550 - loss: 0.6887
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.5300 - loss: 0.6895
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4300 - loss: 0.7162
# Test loss: 0.7161619067192078
# Test accuracy: 0.4300000071525574

# %% [markdown]
# Exercise 3: Use Batch Normalization
#
# Objective: Implement batch normalization to improve training stability.
#
# Instructions:
#
# Add batch normalization layers after each hidden layer.
# Recompile, train, and evaluate the model.

# %%
from tensorflow.keras.layers import Dropout, Input, Dense
from tensorflow.keras.models import Model

#definir a camada de entrada
input_layer=Input(shape=(20,)) #shape = numeros de vetores de entrada

#add camadas ocultas com batch
hidden_layer1=Dense(64, activation='relu')(input_layer)
batch_norm_layer1 = BatchNormalization()(hidden_layer1)
hidden_layer2=Dense(64, activation='relu')(batch_norm_layer1)
batch_norm_layer2 = BatchNormalization()(hidden_layer2)

#definir a camada de saida
output_layer=Dense(1,activation='sigmoid')(batch_norm_layer2)

#create the model
model = Model(inputs=input_layer,outputs=output_layer)
model.summary()

#compilar o modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

#treinar o modelo
model.fit(X_train, y_train, epochs=10, batch_size=32)

#avaliar desempenho do modelo
loss, accuracy=model.evaluate(X_test, y_test)
print(f'Test loss: {loss}')
print(f'Test accuracy: {accuracy}')
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)      │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,081 (23.75 KB)
#  Trainable params: 5,825 (22.75 KB)
#  Non-trainable params: 256 (1.00 KB)
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4770 - loss: 0.8519
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5590 - loss: 0.7114
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5950 - loss: 0.6730
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - accuracy: 0.6160 - loss: 0.6492
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6420 - loss: 0.6386
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - accuracy: 0.6490 - loss: 0.6268
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6710 - loss: 0.6038
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6670 - loss: 0.6007
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7040 - loss: 0.5829
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7190 - loss: 0.5658
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5000 - loss: 0.7126
# Test loss: 0.7126281261444092
# Test accuracy: 0.5
